# %%
import pandas as pd
import numpy as np

# %%
consumer = pd.read_excel(r"C:\Users\amanb\Downloads\Customer_Complaints\Consumer_Complaints.xlsx")

# %%
consumer
# Out:
#        Complaint ID Submitted via Date submitted Date received State  \
# 0           4848023      Referral     2021-10-24    2021-10-27    NY
# 1           3621464           Web     2020-04-24    2020-04-24    FL
# 2           5818349           Web     2022-07-27    2022-07-27    CA
# 3           7233015      Referral     2023-07-10    2023-07-11    CA
# 4           5820224      Referral     2022-07-27    2022-07-28    VA
# ...             ...           ...            ...           ...   ...
# 62511       2501211           Web     2017-06-04    2017-06-04    TX
# 62512       2472406      Referral     2017-05-01    2017-05-05    VA
# 62513       3704015           Web     2020-06-17    2020-06-17    TN
# 62514       2488973      Referral     2017-05-19    2017-05-19    GA
# 62515       6234542           Web     2022-11-22    2022-11-22    CA
#
#                                                  Product  \
# 0                                               Mortgage
# ...

# %%
consumer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62516 entries, 0 to 62515
# Data columns (total 12 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   complaint id                  62516 non-null  int64
#  1   submitted via                 62516 non-null  object
#  2   date submitted                62516 non-null  datetime64[ns]
#  3   date received                 62516 non-null  datetime64[ns]
#  4   state                         62516 non-null  object
#  5   product                       62516 non-null  object
#  6   sub_product                   62516 non-null  object
#  7   issue                         62516 non-null  object
#  8   sub_issue                     62516 non-null  object
#  9   company public response       62516 non-null  object
#  10  company response to consumer  62516 non-null  object
#  11  timely response?              62516 non-null  object
# ...

# %%
consumer.describe()
# Out:
#        Complaint ID                 Date submitted  \
# count  6.251600e+04                          62516
# mean   4.512642e+06  2020-11-24 16:07:14.883869696
# min    2.471340e+06            2017-05-01 00:00:00
# 25%    3.254020e+06            2019-05-22 00:00:00
# 50%    4.178582e+06            2021-03-02 00:00:00
# 75%    5.771284e+06            2022-07-14 00:00:00
# max    7.458912e+06            2023-08-28 00:00:00
# std    1.442917e+06                            NaN
#
#                        Date received
# count                          62516
# mean   2020-11-25 21:31:05.071341568
# min              2017-05-01 00:00:00
# 25%              2019-05-28 00:00:00
# 50%              2021-03-03 00:00:00
# 75%              2022-07-15 00:00:00
# max              2023-08-28 00:00:00
# std                              NaN

# %%
consumer.isnull().sum()
# Out:
# Complaint ID                        0
# Submitted via                       0
# Date submitted                      0
# Date received                       0
# State                               0
# Product                             0
# Sub-product                         7
# Issue                               0
# Sub-issue                       10858
# Company public response          2175
# Company response to consumer        0
# Timely response?                 1494
# dtype: int64

# %%
consumer.shape
# Out:
# (62516, 12)

# %%
consumer["Sub-issue"] = consumer["Sub-issue"].fillna("Not defined")

# %%
consumer.isnull().sum()
# Out:
# Complaint ID                       0
# Submitted via                      0
# Date submitted                     0
# Date received                      0
# State                              0
# Product                            0
# Sub-product                        7
# Issue                              0
# Sub-issue                          0
# Company public response         2175
# Company response to consumer       0
# Timely response?                1494
# dtype: int64

# %%
consumer["Company public response"] = consumer["Company public response"].fillna("Not provided")

# %%
consumer["Timely response?"] = consumer["Timely response?"].fillna("N.A")

# %%
consumer.isnull().sum()
# Out:
# Complaint ID                    0
# Submitted via                   0
# Date submitted                  0
# Date received                   0
# State                           0
# Product                         0
# Sub-product                     7
# Issue                           0
# Sub-issue                       0
# Company public response         0
# Company response to consumer    0
# Timely response?                0
# dtype: int64

# %%
consumer["Sub-product"] = consumer["Sub-product"].fillna("N.A")

# %%
consumer.duplicated().sum()
# Out:
# np.int64(0)

# %%
consumer.columns
# Out:
# Index(['Complaint ID', 'Submitted via', 'Date submitted', 'Date received',
#        'State', 'Product', 'Sub-product', 'Issue', 'Sub-issue',
#        'Company public response', 'Company response to consumer',
#        'Timely response?'],
#       dtype='object')

# %%
consumer.columns = consumer.columns.str.replace("-","_")
consumer.columns = consumer.columns.str.lower()

# %%
consumer.columns
# Out:
# Index(['complaint id', 'submitted via', 'date submitted', 'date received',
#        'state', 'product', 'sub_product', 'issue', 'sub_issue',
#        'company public response', 'company response to consumer',
#        'timely response?'],
#       dtype='object')

# %%
consumer = consumer.rename(columns = {"timely_response?" : "timely_response"})

# %%
consumer.columns
# Out:
# Index(['complaint id', 'submitted via', 'date submitted', 'date received',
#        'state', 'product', 'sub_product', 'issue', 'sub_issue',
#        'company public response', 'company response to consumer',
#        'timely response?'],
#       dtype='object')

# %%
consumer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62516 entries, 0 to 62515
# Data columns (total 12 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   complaint id                  62516 non-null  int64
#  1   submitted via                 62516 non-null  object
#  2   date submitted                62516 non-null  datetime64[ns]
#  3   date received                 62516 non-null  datetime64[ns]
#  4   state                         62516 non-null  object
#  5   product                       62516 non-null  object
#  6   sub_product                   62516 non-null  object
#  7   issue                         62516 non-null  object
#  8   sub_issue                     62516 non-null  object
#  9   company public response       62516 non-null  object
#  10  company response to consumer  62516 non-null  object
#  11  timely response?              62516 non-null  object
# ...

# %%
consumer.count()
# Out:
# complaint id                    62516
# submitted via                   62516
# date submitted                  62516
# date received                   62516
# state                           62516
# product                         62516
# sub_product                     62516
# issue                           62516
# sub_issue                       62516
# company public response         62516
# company response to consumer    62516
# timely response?                62516
# dtype: int64

# %%
consumer.columns = consumer.columns.str.replace(" ","_")

# %%
consumer = consumer.rename(columns = {"timely_response?" : "timely_response"})

# %%
consumer.columns
# Out:
# Index(['complaint_id', 'submitted_via', 'date_submitted', 'date_received',
#        'state', 'product', 'sub_product', 'issue', 'sub_issue',
#        'company_public_response', 'company_response_to_consumer',
#        'timely_response'],
#       dtype='object')

# %%
from sqlalchemy import create_engine

engine = create_engine("mysql+pymysql://root:aman123@localhost:3306/Financial_complaints")

consumer.to_sql(
    name="complaints_analysis",
    con=engine,
    if_exists="replace",   
    index=False
)
# Out:
# 62516

# %%
consumer.to_csv("complaints_analysis.csv",
index = False, encoding = "utf-8-sig")
